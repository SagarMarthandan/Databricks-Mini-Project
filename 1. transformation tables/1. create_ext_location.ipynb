-- %% [markdown]
-- Create ext location
--
-- 1. Bronze
-- 2. Silver
-- 3. Gold

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_ext_stg_bronze
URL 'abfss://bronze@databrickscourseucextsg.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-ext-storage-creds`);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
%fs
ls "abfss://bronze@databrickscourseucextsg.dfs.core.windows.net"
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th><th>modificationTime</th></tr></thead><tbody><tr><td>abfss://bronze@databrickscourseucextsg.dfs.core.windows.net/drivers.json</td><td>drivers.json</td><td>180812</td><td>1763905021000</td></tr><tr><td>abfss://bronze@databrickscourseucextsg.dfs.core.windows.net/results.json</td><td>results.json</td><td>7165641</td><td>1763905022000</td></tr></tbody></table></div>

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_ext_stg_silver
URL 'abfss://silver@databrickscourseucextsg.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-ext-storage-creds`);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

-- %%
CREATE EXTERNAL LOCATION IF NOT EXISTS databricks_ext_stg_gold
URL 'abfss://gold@databrickscourseucextsg.dfs.core.windows.net/'
WITH (STORAGE CREDENTIAL `databricks-ext-storage-creds`);
-- Out:
-- <style scoped>
--   .table-result-container {
--     max-height: 300px;
--     overflow: auto;
--   }
--   table, th, td {
--     border: 1px solid black;
--     border-collapse: collapse;
--   }
--   th, td {
--     padding: 5px;
--   }
--   th {
--     text-align: left;
--   }
-- </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
