# %%
dbutils.fs.ls('abfss://demo@databrickscourseucextsg.dfs.core.windows.net/')
# Out:
# [FileInfo(path='abfss://demo@databrickscourseucextsg.dfs.core.windows.net/circuits.csv', name='circuits.csv', size=10044, modificationTime=1763903690000)]
